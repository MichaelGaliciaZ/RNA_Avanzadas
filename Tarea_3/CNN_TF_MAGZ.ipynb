# %%
class CustomCNN(tf.Module):
    def __init__(self):
        super.__init__()
        self.Layer_1_Weights_Filter = tf.Variable(np.random.rand(5,5,1,16),
                                                name="Layer_1_Weights",
                                                dtype="float32")
        self.Layer_1_Bias= tf.Variable(np.random.rand(16),
                                        name="Layer_1_Bias",
                                        dtype="float32")
        
        self.Layer_2_Weights_Filter = tf.Variable(np.random.rand(5,5,16,32),
                                                name="Layer_2_Weights",
                                                dtype="float32")

        self.Layer_2_Bias= tf.Variable(np.random.rand(32),
                                        name="Layer_2_Bias",
                                        dtype="float32")

        self.Layer_3_Weights_Filter = tf.Variable(np.random.rand(5,5,32,64),
                                                name="Layer_3_Weights",
                                                dtype="float32")

        self.Layer_3_Bias= tf.Variable(np.random.rand(64),
                                        name="Layer_3_Bias",
                                        dtype="float32")

        self.Layer_1_Weights_Dense=tf.Variable(np.random.randn(0*0*64,1024),
                                                name="Layer_1_Weights_Dense",
                                                dtype="float32")

        self.Layer_1_Bias_Dense=tf.Variable(np.random.randn(1024),
                                            name="Layer_1_Bias_Dense",
                                            dtype="float32")

        self.Output_Layer=tf.Variable(np.random.randn(1024,10),
                                        name="Output_Layer",
                                        dtype="float32")
        
        self.Output_Bias=tf.Variable(np.random.randn(10),
                                    name="Output_Bias",
                                    dtype="float32")

    def Conv2D(self,x,W,b,strides=1):
        x=tf.nn.conv2d(x,W,strides=[1,strides,strides,1],padding='SAME')
        x=tf.nn.bias_add(x,b)
        x=tf.nn.relu(x)
        return x
    def MaxPool(self,x,k=2):
        return tf.nn.max_pool(x,ksize=[1,k,k,1],
                                strides=[1,k,k,1],
                                padding='SAME')
    def __call__(self,x):

        x=tf.cast(x,tf.float32)

        # img=x.reshape(x,shape=[-1,28,28,1])

        # L1=Conv2D(img,self.Layer_1_Weights_Filter,self.Layer_1_Bias)

        # L1=MaxPool(L1)

        # L2=Conv2D(L1,self.Layer_2_Weights_Filter,self.Layer_2_Bias)

        # L2=MaxPool(L2)

        


    



    def predict(self, x):
        pass

class CustomNN():
    def __init__(self) -> None:
        pass
